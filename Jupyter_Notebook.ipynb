# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Keli Wen
#
# Student

# %% [markdown]
# *I am interested in data science because I believe I can create multi-person value through data science*

# %% [markdown]
# Calculate factorial of a number `n`

# %%
def factorial(x):
    if x == 0 or x == 1:
        return 1
    return x * factorial(x - 1)
print(factorial(5))
# Out:
# 120

# %% [markdown]
# ---
#
#
# > Hello World
#
# ```python
# print("Hello World")
# ```
